# %%
import torch
import torch.nn as nn
from torchvision import models, transforms
from torch.utils.data import DataLoader
from PIL import Image
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity
import os
import pickle
import matplotlib.pyplot as plt
from PIL import Image
import shutil

# %% [markdown]
# ### unzip_file(zip_file): 파일 압축 해제

# %%
import zipfile

def unzip_file(zip_file):
  with zipfile.ZipFile(zip_file, 'r') as zip_ref:
      zip_ref.extractall()

# %%
unzip_file('angry_face_n.zip')

# %%
unzip_file('angry_face.zip')
unzip_file('angry_body.zip')

# %% [markdown]
# ### to_pkl(file_path, feature_vector): 특징벡터를 pkl 파일로 저장

# %%
def to_pkl(file_path,feature_vector):
  with open(file_path, 'wb') as f:
    pickle.dump(feature_vector, f)

# %% [markdown]
# ### pkl_load(file_path): pkl 파일을 로드

# %%
def pkl_load(file_path):
  with open(file_path, 'rb') as f:
    data = pickle.load(f)
  return data

# %% [markdown]
# ### feature_dict(file_path): 이미지에 대해 resnet으로 feature 추출하고 저장

# %%
def feature_dict(file_path):
    # 전처리
    preprocess = transforms.Compose([
        transforms.Resize((224, 224)),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
    ])
    # resnet 사전학습 상태로 로드
    model = models.resnet18(pretrained=True)
    model = nn.Sequential(*list(model.children())[:-1])  # 마지막 분류 레이어 제거
    model.eval()

    feature_dict = {}
    # 특징 벡터 추출
    image_paths = [os.path.join(file_path, img) for img in sorted(os.listdir(file_path))]
    for img_path in image_paths:
        if os.path.isfile(img_path):  
            image_name = os.path.basename(img_path) 
            image = Image.open(img_path).convert("RGB")
            image = preprocess(image).unsqueeze(0)
            with torch.no_grad():
                feature = model(image).squeeze().numpy()
            feature_dict[image_name] = feature
    return feature_dict

# %% [markdown]
# ### mean_vector(file_path): feature 값들의 mean vector 계산

# %%
def mean_vector(file_path):
  fdict=feature_dict(file_path)
  vectors = list(fdict.values())
  mean_vector = np.mean(vectors, axis=0)
  return mean_vector

# %% [markdown]
# # cor(file_path, num, feature_dict, mean_vector) 반환 함수 정의
# -> 유사도 구하기

# %% [markdown]
# ### cor(file_path, feature_dict, mean_vector): 전체 feature와 mean vector의 유사도를 계산 및 정렬

# %%
def cor(file_path,feature_dict, mean_vector):

    similarity_list = []

    for image_name, feature in feature_dict.items():
        similarity = cosine_similarity([feature], [mean_vector])[0][0]
        similarity_list.append((image_name, similarity))

    similarity_list.sort(key=lambda x: x[1], reverse=True)
    
    image_list = []
    for image_name, similarity in similarity_list:
        image_path = os.path.join(file_path, image_name)
        image_list.append(image_path)
    return image_list

# %% [markdown]
# ### cor_show(image_list, num): 유사도 높은 순으로 num 만큼 이미지 시각화

# %%
def cor_show(image_list, num):
    num_images = min(num, len(image_list))  # num 또는 전체 이미지 수 중 작은 값
    num_cols = 4  
    num_rows = (num_images // num_cols) + (num_images % num_cols > 0) 
    extra_space_rows = (num_images // 20)  # 20개마다 추가 공간을 확보

    plt.figure(figsize=(20, (num_rows + extra_space_rows) * 5)) 

    current_row_offset = 0  

    for i, img_path in enumerate(image_list[:num_images]):  
        # 20개마다 줄바꿈 간격 
        if i > 0 and i % 20 == 0:
            current_row_offset += 1

        row = (i // num_cols) + current_row_offset
        col = i % num_cols

        plt.subplot(num_rows + extra_space_rows, num_cols, row * num_cols + col + 1)
        img = Image.open(img_path)
        plt.imshow(img)
        plt.axis('off')

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### file_copy(img_list, num, new_folder): 폴더에 num개의 이미지 복사

# %%
def file_copy(img_list, num, new_folder):

  for i, (img_path, _) in enumerate(img_list[:num]):
      if os.path.exists(img_path):  
          shutil.copy(img_path, new_folder)

  print(f"{new_folder} 폴더에 {num}개의 이미지 복사가 완료되었습니다.")

# %% [markdown]
# ### file_move(dest_folder, image_list, feature_dict, num): 파일을 dest_folder로 이동

# %%
def file_move(dest_folder, image_list, feature_dict, num):
    os.makedirs(dest_folder, exist_ok=True)  
    moved_files = []  

    for file_path in image_list[:num]:  # 최대 num개의 파일만 처리
        if os.path.exists(file_path):  
            file_name = os.path.basename(file_path)  
            new_path = os.path.join(dest_folder, file_name)
            shutil.move(file_path, new_path)
            moved_files.append(file_name)

    # feature_dict에서 이동된 파일 제거
    updated_feature_dict = {key: value for key, value in feature_dict.items() if key not in moved_files}
    return updated_feature_dict

# %% [markdown]
# # 학습 데이터 구성

# %% [markdown]
# ## angry 학습 데이터 (500개)
# -> angry_face, angry_body, angry_face_n에 대해 각각 유사한 이미지 추출

# %%
unzip_file('angry_face.zip')
unzip_file('angry_body.zip')
unzip_file('angry_face_n.zip')
unzip_file('dog_angry_crop_img.zip')

# %% [markdown]
# 전체 angry 이미지에 대해 feature 추출 -> angry_feature_dict.pkl

# %%
angry_feature_dict=pkl_load('angry_feature_dict.pkl')

# %% [markdown]
# 대표 이미지들에 대해 mean_vector 계산

# %%
ang_face_vector=mean_vector('angry_face')
ang_body_vector=mean_vector('angry_body')
ang_face_n_vector=mean_vector('angry_face_n')
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100%|██████████| 44.7M/44.7M [00:00<00:00, 183MB/s]

# %% [markdown]
# ### angry_face_vector와 유사한 이미지 220장 추출

# %%
ang_face_list=cor('dog_angry_crop_img',220,angry_feature_dict,ang_face_vector)

# %%
folder_path = '/content/dog_angry_crop_img'

if os.path.exists(folder_path): 
    file_count = len([f for f in os.listdir(folder_path) if os.path.isfile(os.path.join(folder_path, f))])
    print(f"폴더 '{folder_path}'에 있는 파일 개수: {file_count}")
else:
    print(f"폴더 '{folder_path}'가 존재하지 않습니다.")
# Out:
# 폴더 '/content/dog_angry_crop_img'에 있는 파일 개수: 740

# %% [markdown]
# 전체 angry 데이터 중에서 ang_face_vector와 유사한 데이터 220개를 새로운 폴더로 이동

# %%
angry_feature_dict=file_move('/content/angry_train_img',ang_face_list,angry_feature_dict)

# %%
folder_path = '/content/dog_angry_crop_img'

if os.path.exists(folder_path): 
    file_count = len([f for f in os.listdir(folder_path) if os.path.isfile(os.path.join(folder_path, f))])
    print(f"폴더 '{folder_path}'에 있는 파일 개수: {file_count}")
else:
    print(f"폴더 '{folder_path}'가 존재하지 않습니다.")
# Out:
# 폴더 '/content/dog_angry_crop_img'에 있는 파일 개수: 520

# %% [markdown]
# ### angry_body_vector와 유사한 이미지 220장 추출

# %%
ang_body_list=cor('dog_angry_crop_img',220,angry_feature_dict,ang_body_vector)

# %% [markdown]
# 남은 angry 데이터 중에서 ang_body_vector와 유사한 데이터 220개를 새로운 폴더로 이동

# %%
angry_feature_dict=file_move('/content/angry_train_img',ang_face_list,angry_feature_dict)

# %% [markdown]
# ### angry_face_n_vector와 유사한 이미지 60장 추출

# %%
ang_face_n_list=cor('dog_angry_crop_img',60,angry_feature_dict,ang_face_n_vector)
# Out:
# [('Md5JkFuXpbftuCAxmpqIeTpqNNwbSB423_crop_1.jpg', 0.91637385), ('7p0ocgRn42u21i2utwENqotyqJoX6P751_crop_1.jpg', 0.915748), ('j5KdqDqt6W928Mmokf8zWXwj7tH6Hi884_crop_1.jpg', 0.8943096), ('lwJ10itB6vdK8vtXVBCw9VjAkQJi4o76_crop_1.jpg', 0.8867295), ('SoVoK90zyhVmYP3AdEldtMmXQTHWJm643_crop_1.jpg', 0.88565063), ('LATTp1CcV5vi3ZgCXcTkDDOnq7scFb167_crop_1.jpg', 0.8824178), ('wKtKH0fj4VG0ic2BlEyKgpGO6YGOm1225_crop_1.jpg', 0.8760853), ('PmM7uMpAn8pQn9rWOG455vhSsUT0Xv730_crop_1.jpg', 0.87140036), ('XiL5OnGXaN7icBLe7Y3GTIecOMKy8z566_crop_1.jpg', 0.86924374), ('N1tCByCeHkRvMiECUoUelkZULbo4Aq359_crop_1.jpg', 0.8626189), ('a4GsaAzQhY00zmyR14x7BX1K8LaACM586_crop_1.jpg', 0.8602503), ('cc79mOhzoG4YClBSctDepqTNwwN7Ld632_crop_1.jpg', 0.8584822), ('OwyzX6VUIHYHejdMcEb7GK6IMRR5VA774_crop_2.jpg', 0.8577877), ('Z1LvV6pZShKUjgtpuTqjPpQixzJWXi148_crop_1.jpg', 0.85765666), ('iCn0DKqylzUMJGWkVR81Muk6HIMrvc919_crop_1.jpg', 0.8504272), ('0rdx3OrwENAIWpp9Bunro1ku6Zwbqv6_crop_1.jpg', 0.8497025), ('7kgoRu1DY8ZxkMR5NFI6ZQV3yqbdPj707_crop_1.jpg', 0.84684503), ('zGZDewph699wNh5YGzypBdI9sMRpVw452_crop_1.jpg', 0.84593034), ('cyUKneTqM6NkbftL1frU5bynMvqCqS164_crop_1.jpg', 0.8436078), ('BDg8lfoPX7kxWn55ARHLTh8hmNhqbh970_crop_1.jpg', 0.8417975), ('pmKpu8yX4eI3wqMIPzrqksQ4r3ZOYP631_crop_1.jpg', 0.84143245), ('JCGi0ioboFA6hlc488hh0M7zWGJScV71_crop_1.jpg', 0.83677316), ('vX4WhmnDzBvbJpHHShtlLxl1hEynsu630_crop_1.jpg', 0.83648765), ('S6LMVe2le8hLy5gwHHEhnoZkmmZKZh964_crop_1.jpg', 0.8349471), ('HTVLe7vXEqKlUCRBCTPOXLiwSi7al0451_crop_1.jpg', 0.8313278), ('E0ifYHUzor2NCut7zy5A4jeMIUFULV792_crop_2.jpg', 0.82897943), ('yymIKCWkoPs4nSX0NWZPbHVFU6No6e598_crop_1.jpg', 0.8266437), ('xqP44jQtndpPSjiQCxY07bEe5vJLdO779_crop_1.jpg', 0.8221448), ('xDiWudo2F545at18mCKWvbWlvnGDv057_crop_3.jpg', 0.81891304), ('t0RLdPUSNrZYbsTNk2XuAPCpN19Enb54_crop_1.jpg', 0.81848097), ('4H6XZqQWKsjmr20WPHT27t5MFXgEX2189_crop_1.jpg', 0.8176995), ('VrRIoUQZITqCMhttYCj9c0dnQ12Yme918_crop_1.jpg', 0.8132875), ('8hbzAvPkZ5Y5CNneibpxmtsPw5RzSl197_crop_1.jpg', 0.8090593), ('rRKhKntRbdNvVjUMs0pob9tCCvmCrJ240_crop_1.jpg', 0.8083597), ('GsuLD6JJ7bBpxlD7iGepKdWPpeFTTz7_crop_1.jpg', 0.8067642), ('Vb7ERbhQ7iwt1Kqni38gggXcdRFHiL296_crop_1.jpg', 0.80574656), ('vgZizFdaWMIVOQ9aX96j0rMUYrAzep790_crop_1.jpg', 0.80486655), ('1OIYiVdFbBN5bnKkFGCbLyBcuUrpww110_crop_1.jpg', 0.80389345), ('lp2VpbxUDw41VRL8V5qZWIgWxUUW2K733_crop_2.jpg', 0.80354667), ('fGH6HIXKpmzF8uN7uPt1YH3ZcgMKCh122_crop_1.jpg', 0.80339783), ('pGUxlojcYNJ9VAdkjHGeDmok3vYlEb349_crop_1.jpg', 0.80337083), ('aiQ3pRIXkOeb3rWRcoIpbp5UlXwx4U363_crop_1.jpg', 0.80174613), ('1dndVMGjpetphxG6rVVempH947atN9743_crop_2.jpg', 0.80110604), ('JVmQ8Ge5IGDQLvbKQV1c2WunSFQyQ92_crop_1.jpg', 0.79535526), ('nbjkFT1TSAGmmjxXGli9wKdJTVYyOE196_crop_2.jpg', 0.7951392), ('92xegFRdPjKk3HoCCPHtow6N3731dP898_crop_1.jpg', 0.79497755), ('LVkN2kvRzF5DmF40ZbJ6QCgu551Ekj405_crop_1.jpg', 0.79497313), ('0tVivKVWy9s7Zp3vR7LN1syiMBfAoR375_crop_1.jpg', 0.7924131), ('P703tjXIsYh3xFHJGkSj8eymp39GYh738_crop_1.jpg', 0.7922075), ('yLVpgPD9klsyWE6W9vGrf2MjHaykjV859_crop_1.jpg', 0.7908659), ('G4mh7ehkxmWhMlQS6T7dNyuEEyBR1p762_crop_1.jpg', 0.78953505), ('4bzTknCpzIwJDHXTsG7ZDPfMNOu4rs355_crop_1.jpg', 0.7891951), ('Ooex03stheot7z1RkyUFf9TzmlZw1E600_crop_1.jpg', 0.7875945), ('MR60V7xsNufWHunzAENLYoxV87D1ge193_crop_1.jpg', 0.78732157), ('RUU3ouDj2c7UZK3JlBqoiOZEZ8dl2j177_crop_1.jpg', 0.7872557), ('bOobKTMMZOORNwilcfcUQ77w9K1Izl130_crop_1.jpg', 0.78674054), ('ErpETv00Y7pwxNeDD1KkeJ6j06wuMh241_crop_1.jpg', 0.7867003), ('9YPxCPm9Kw7gteTkdWlEjLwoBmyaml102_crop_1.jpg', 0.7854453), ('YOl3FW5SRUiKGNQx6javZP4CoPowCv853_crop_1.jpg', 0.7853843), ('Ov9tosvYBQPyI69xNqqBY3fzwdJxhy448_crop_1.jpg', 0.78526914), ('3Yzy86q8gSFC1Lc8z6SdJjPjIxnmO7677_crop_3.jpg', 0.785082), ('ragugZuuMEvt43mlvGq6AIlsOIiwxW339_crop_1.jpg', 0.7850579), ('BHTJ9iRRpygZbzkvrJOGQrIRN1IoZM301_crop_2.jpg', 0.78424513), ('HWwRF8l7Gb62JhUHILKsH97uUbO2FQ776_crop_2.jpg', 0.7841797), ('MS8AGnvmV7ZF3ZZrIm4c1ENpqGRXlv330_crop_1.jpg', 0.78346324), ('mlLdct7Icc4Hi5 ...

# %% [markdown]
# 남은 angry 데이터 중에서 ang_face_n_vector와 유사한 데이터 60개를 새로운 폴더로 이동

# %%
angry_feature_dict=file_move('/content/angry_train_img',ang_face_n_list,angry_feature_dict)

# %%
folder_path = '/content/angry_train_img'

if os.path.exists(folder_path):
    file_count = len([f for f in os.listdir(folder_path) if os.path.isfile(os.path.join(folder_path, f))])
    print(f"폴더 '{folder_path}'에 있는 파일 개수: {file_count}")
else:
    print(f"폴더 '{folder_path}'가 존재하지 않습니다.")
# Out:
# 폴더 '/content/angry_train_img'에 있는 파일 개수: 500

# %%
shutil.make_archive('angry_train_img', 'zip', 'angry_train_img')
# Out:
# '/content/angry_train_img.zip'

# %% [markdown]
# ## happy 학습 데이터 (500개)
# -> happy_face, happy_body, play에 대해 각각 유사한 이미지 추출

# %%
unzip_file('happy_face.zip')
unzip_file('happy_body.zip')
unzip_file('dog_happy_crop_img.zip')

# %% [markdown]
# 전체 happy 이미지에 대해 feature 추출 -> happy_feature_dict.pkl

# %%
happy_feature_dict=pkl_load('happy_feature_dict.pkl')

# %% [markdown]
# 대표 이미지들에 대해 mean_vector 계산

# %%
hap_face_vector=mean_vector('happy_face')
hap_body_vector=mean_vector('happy_body')
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100%|██████████| 44.7M/44.7M [00:00<00:00, 133MB/s]

# %% [markdown]
# ### hap_face_vector와 유사한 이미지 200장 추출

# %%
hap_face_list=cor('dog_happy_crop_img',200,happy_feature_dict,hap_face_vector)
# Out:
# [('lXz4bZwzWzQwtaWAjGqj3cmaCjg6Iv606_crop_1.jpg', 0.8713993), ('happy_dog_830_crop_1.jpg', 0.8648623), ('happy_dog_89_crop_1.jpg', 0.86461633), ('happy_dog_831_crop_1.jpg', 0.86442626), ('xt37zG27DNAubuAtHNh2FRPe42Xa8M677_crop_1.jpg', 0.86386025), ('2gUa6Q1EmPsDanb1TRdPt6Im0llmf7616_crop_1.jpg', 0.8611378), ('happy_dog_747_crop_1.jpg', 0.860144), ('happy_dog_600_crop_1.jpg', 0.85986435), ('tUfV37QU3HSxfyz6LBpktlZ53SPwqc835_crop_1.jpg', 0.8597549), ('happy_dog_254_crop_1.jpg', 0.85746825), ('happy_dog_78_crop_1.jpg', 0.8557918), ('happy_dog_560_crop_1.jpg', 0.8551856), ('happy_dog_673_crop_1.jpg', 0.8544166), ('happy_dog_34_crop_1.jpg', 0.8528702), ('happy_dog_682_crop_1.jpg', 0.851732), ('PNBP1LhXU0LIbTu35bp0E5ft6xMEH0696_crop_1.jpg', 0.85120404), ('o1xdQR6vUihH6EgnM6vsq4LD1Miry5673_crop_1.jpg', 0.85119766), ('pJe6KmRDKqiuNMvjoV0I8t9gBg3Ps6713_crop_1.jpg', 0.8506112), ('KtX6RcyAAB71RmzQ22vIfBGFhKw451691_crop_1.jpg', 0.85057217), ('happy_dog_68_crop_1.jpg', 0.8502045), ('happy_dog_754_crop_1.jpg', 0.8502028), ('bKHJQhwkJ5j4s7PKcVTzkctJ9YJKtv697_crop_1.jpg', 0.8498949), ('vJCDj54I8j1aparNFWBtv3v1JuE6U7762_crop_1.jpg', 0.8494066), ('happy_dog_494_crop_1.jpg', 0.8489603), ('happy_dog_23_crop_1.jpg', 0.84886545), ('EyKARIefJP13yQdbbtzI43EGTmL8Oo804_crop_1.jpg', 0.8488216), ('56UpTuGmYHwGdoJ37XaoQF9lAbFTX0576_crop_1.jpg', 0.8485688), ('happy_dog_356_crop_1.jpg', 0.8483579), ('happy_dog_904_crop_1.jpg', 0.84824634), ('tsnyf2VcxUHzmy1R8G0P3kawPH6GMd718_crop_1.jpg', 0.8465146), ('PmIJQcqi3mlLcR6LFkA7ij4DLTuYuD572_crop_1.jpg', 0.8464228), ('happy_dog_85_crop_1.jpg', 0.84629065), ('K7p4yGXnUm52HWAANexbjTpWzgIsLp781_crop_1.jpg', 0.8461064), ('happy_dog_43_crop_1.jpg', 0.84605086), ('YZcrxN327oo685MbuzmghpoWXMpZrn820_crop_1.jpg', 0.84598863), ('IYJnvZSMBIRxTTWgQpIYarqXJcp5AZ717_crop_1.jpg', 0.84583926), ('happy_dog_813_crop_1.jpg', 0.84548885), ('CvVOIkdxZzf2JxTDz7SFUCnPUHFPiS2_crop_1.jpg', 0.8446137), ('happy_dog_707_crop_1.jpg', 0.8443274), ('N3usn6ELaKFDQVlJE9johAtjIxYCFK574_crop_1.jpg', 0.8440369), ('happy_dog_323_crop_1.jpg', 0.84361345), ('2OLkWxmeUiHwvuR6eKTwX1GmBiJq7y614_crop_1.jpg', 0.8431266), ('happy_dog_457_crop_1.jpg', 0.84308064), ('happy_dog_761_crop_1.jpg', 0.8428062), ('happy_dog_858_crop_1.jpg', 0.8421447), ('happy_dog_79_crop_1.jpg', 0.8417418), ('happy_dog_992_crop_1.jpg', 0.8414188), ('happy_dog_524_crop_1.jpg', 0.841295), ('happy_dog_304_crop_1.jpg', 0.8409307), ('happy_dog_498_crop_1.jpg', 0.8401747), ('happy_dog_47_crop_1.jpg', 0.8400885), ('happy_dog_332_crop_1.jpg', 0.840039), ('vnr0w5xCT5pYOBfTQssIgLULQY9IrE580_crop_1.jpg', 0.8398446), ('t0NkSYTaKn2fbd3P6ljqHuIttT0BKn506_crop_3.jpg', 0.8396024), ('happy_dog_301_crop_1.jpg', 0.838879), ('happy_dog_35_crop_1.jpg', 0.8386928), ('happy_dog_343_crop_1.jpg', 0.8381995), ('happy_dog_766_crop_1.jpg', 0.8381897), ('1KdEGoZwPog5YjCMf2TiptauslILYK862_crop_1.jpg', 0.8379092), ('happy_dog_322_crop_1.jpg', 0.8378043), ('happy_dog_608_crop_1.jpg', 0.8377272), ('happy_dog_20_crop_1.jpg', 0.8374455), ('happy_dog_430_crop_6.jpg', 0.8374399), ('happy_dog_717_crop_1.jpg', 0.83715796), ('ICDXsTb5htzCwQg7wEEurTtMpmYKNm590_crop_1.jpg', 0.836712), ('happy_dog_169_crop_1.jpg', 0.8366136), ('happy_dog_128_crop_1.jpg', 0.8365286), ('happy_dog_694_crop_1.jpg', 0.8365084), ('happy_dog_629_crop_1.jpg', 0.83625), ('happy_dog_115_crop_1.jpg', 0.83617425), ('AN7wf1UnHMl0ehp1XRPLJHf7U5Fl00636_crop_2.jpg', 0.83604705), ('fASHRePhtrxPPSrrBUPgngUPoVxBLT450_crop_1.jpg', 0.8358923), ('4wmUrmlvdrWwc4Awq8zNDXT32vYVq3746_crop_1.jpg', 0.83576286), ('happy_dog_983_crop_1.jpg', 0.8356216), ('happy_dog_573_crop_1.jpg', 0.834379), ('happy_dog_229_crop_1.jpg', 0.83412033), ('oQZvAxMk0NjEjFmSiQ54OGQU4hslzW797_crop_1.jpg', 0.8336629), ('happy_dog_977_crop_1.jpg', 0.833634), ('E6GDYcbebGRiYOxIAugFKRTG1jgY74631_crop_1.jpg', 0.8334397), ('happy_dog_46_crop_1.jpg', 0.83258677), ('Lz6SjBfhJ3gQ0r4lnoAmV9JRhWyx9I745_crop_1.jpg', 0.83223826), ('happy_dog_150_crop_1.jpg', 0.832187), ('happy_dog_461_crop_1.jpg', 0.8321753 ...

# %%
folder_path = '/content/dog_happy_crop_img'

if os.path.exists(folder_path): 
    file_count = len([f for f in os.listdir(folder_path) if os.path.isfile(os.path.join(folder_path, f))])
    print(f"폴더 '{folder_path}'에 있는 파일 개수: {file_count}")
else:
    print(f"폴더 '{folder_path}'가 존재하지 않습니다.")
# Out:
# 폴더 '/content/dog_happy_crop_img'에 있는 파일 개수: 1810

# %% [markdown]
# 전체 happy 데이터 중에서 hap_face_vector와 유사한 데이터 200개를 새로운 폴더로 이동

# %%
happy_feature_dict=file_move('/content/happy_train_img',hap_face_list,happy_feature_dict)

# %%
folder_path = '/content/dog_happy_crop_img'

if os.path.exists(folder_path): 
    file_count = len([f for f in os.listdir(folder_path) if os.path.isfile(os.path.join(folder_path, f))])
    print(f"폴더 '{folder_path}'에 있는 파일 개수: {file_count}")
else:
    print(f"폴더 '{folder_path}'가 존재하지 않습니다.")
# Out:
# 폴더 '/content/dog_happy_crop_img'에 있는 파일 개수: 1610

# %%
len(happy_feature_dict)
# Out:
# 1610

# %% [markdown]
# ### hap_body_vector와 유사한 이미지 200장 추출

# %%
hap_body_list=cor('dog_happy_crop_img',200,happy_feature_dict,hap_body_vector)
# Out:
# [('ZzHR7fc5ORV22IzGJtHf7YXkwcV1uZ98_crop_1.jpg', 0.8664421), ('happy_dog_90_crop_1.jpg', 0.864267), ('wiR5KjD68669Ni32zj4BhlKlErKs3T88_crop_1.jpg', 0.86399114), ('2bVW67KtR6xL7eph5kzXcLeBMoGojl273_crop_1.jpg', 0.860564), ('happy_dog_778_crop_1.jpg', 0.86004966), ('WhSn5FCAx5qwZFBp1BQ7t4L3aoC9Wt661_crop_1.jpg', 0.85774165), ('happy_dog_165_crop_2.jpg', 0.8548385), ('WRxBcDAqPgvAcOTiERQvkzPFk0yiWW886_crop_1.jpg', 0.85358083), ('lC5nVPgr6J0Q2dmEITgCdkBQz8Vdbp115_crop_1.jpg', 0.8523338), ('PKUrWSe458HpovDqVNJNvy5kcjYm1w729_crop_1.jpg', 0.8518263), ('happy_dog_724_crop_1.jpg', 0.84917414), ('qtRovxpfYJcWpJHkWUBjLOVGhNJ4Ko612_crop_1.jpg', 0.84673613), ('bf4J9U1GphPID6C1PxuodJ3BLj4dsR232_crop_1.jpg', 0.8454961), ('happy_dog_740_crop_1.jpg', 0.84437805), ('HQsw77F0DThSuw0W7cFX3h5n4oI5gB752_crop_1.jpg', 0.84431815), ('happy_dog_903_crop_1.jpg', 0.84385514), ('happy_dog_360_crop_1.jpg', 0.8429209), ('KjTXSxVswZ5LFeuY1XWOStfUbOCmXs85_crop_1.jpg', 0.842752), ('ZEASq8FxIstHibdJjQXsom1DtEfKAk625_crop_1.jpg', 0.8410699), ('happy_dog_710_crop_1.jpg', 0.8407559), ('happy_dog_354_crop_1.jpg', 0.8407372), ('Aa3pfO9DZBSeZ4SyJarg7O2BrePNnP192_crop_1.jpg', 0.83981776), ('happy_dog_413_crop_2.jpg', 0.8390839), ('HR5fTaH8jRZsZM5VwyCO85W3jodjx654_crop_1.jpg', 0.8386908), ('vuMpVchV8bElU3haJeUGIKGLn4excO956_crop_1.jpg', 0.83841014), ('znivn10Ousd4y3Vgw0uKvxfTm7hSvH92_crop_1.jpg', 0.83836865), ('ExI6edxxB6Vls1LGizwJmutLUotXtY128_crop_1.jpg', 0.8383058), ('Db7nCgo8dPM70sJZpmthagWzTdcKHQ724_crop_1.jpg', 0.8381928), ('happy_dog_793_crop_1.jpg', 0.83816713), ('AeROp4YlaFtipd7W7rgpaLVkYmdp5a604_crop_1.jpg', 0.8381461), ('happy_dog_891_crop_1.jpg', 0.8381057), ('happy_dog_8_crop_1.jpg', 0.83715165), ('1rtKfsXhuqXt28uEPA59oZbuqvMmli87_crop_1.jpg', 0.8370489), ('Ws6ZLS4BV6jMIXGWpRCijrw89H1uuL946_crop_1.jpg', 0.8368352), ('bvwnS7B4KiHtytnIwKZmftk2VpqShR914_crop_1.jpg', 0.83661467), ('RWUKbPJNsN9s0mKbYXrxE4ua1nvaPN887_crop_1.jpg', 0.835797), ('xHgryjIve4y3Lpj8ISzW9lZdWCKF7F777_crop_1.jpg', 0.835641), ('2JshHf2MffRx6A4rDs3gumuxM0UG5c744_crop_1.jpg', 0.8353336), ('happy_dog_144_crop_1.jpg', 0.83500934), ('M2vKU3OrxkCcMgBM2HCW6JThtGwvuW652_crop_1.jpg', 0.8348765), ('happy_dog_591_crop_1.jpg', 0.8347197), ('PysiN2FVf2mZw6dtrmXszQQo1gb0Cg120_crop_1.jpg', 0.83452773), ('happy_dog_437_crop_1.jpg', 0.83428943), ('happy_dog_869_crop_1.jpg', 0.83384585), ('zImd4GFVhPLyShB7SYduwARPgMs7Hx520_crop_1.jpg', 0.8333713), ('iwarJUOj6XoYb8n8bYwpHaz0hCz4gj133_crop_1.jpg', 0.8329863), ('TykXYYMc4vEhpP1nPC7dijGMOlOgkS97_crop_1.jpg', 0.83294135), ('J39BTbbBYf51QWiOxVCxscwkP6k2WQ503_crop_1.jpg', 0.8324276), ('FVUSAcqRfJ5zvajk2Ip58axMK2OCW4888_crop_1.jpg', 0.8310361), ('happy_dog_308_crop_2.jpg', 0.83101), ('35AvBz7mbnTW4Sh2MzNuGgR69nnaRV653_crop_1.jpg', 0.82979304), ('lStVl0v7kXqR3hJpNZ0EVvqBTt7TJP949_crop_1.jpg', 0.82892925), ('KPUFEdSueE5kqFSLt6wJa9JUxR3eZP103_crop_1.jpg', 0.82883024), ('happy_dog_419_crop_1.jpg', 0.8283353), ('2IukSIQn4FnHZ14wUvJQOFgzoFJoQp644_crop_1.jpg', 0.82788897), ('happy_dog_582_crop_1.jpg', 0.8276775), ('fOcjsYKFuK1IEl3Xc4x1qU7MSjzKYp667_crop_1.jpg', 0.827301), ('PxCdAISQyUeHUV0fHD29d2NgGX5clS977_crop_1.jpg', 0.827167), ('B0A1whGWqHwhV4o43C451yxC5iFwg7900_crop_1.jpg', 0.82701206), ('VVvPzXZhp4MYrjU5iWb5M4QusTp4m8145_crop_3.jpg', 0.8269031), ('hgVHdl6fQ8t3ftiEsnQAtZmPqOsT48732_crop_1.jpg', 0.8267484), ('oDRjwyCtefkdwvrOdZETu4ixL5sN7i220_crop_1.jpg', 0.8263812), ('happy_dog_6_crop_1.jpg', 0.82628393), ('IJx9QPZmIaPE2TsgEgu2cd5TT6iBlh142_crop_1.jpg', 0.82594174), ('Z6vwfyCe7fqBOhiVAKv5oJ1tk8TTE7639_crop_1.jpg', 0.825837), ('2hAmgXf8tDs3PZ3AQzXpCLGMkzsb09583_crop_1.jpg', 0.8253941), ('n0A0AfBoZmOJUnHsnKylIxoxpsclie91_crop_1.jpg', 0.8249687), ('38zYeDdjuXyTLIezb72M4sfBXetAxS311_crop_1.jpg', 0.8249315), ('V11gnOjIF0wKTo1qTZuHqaFhVqm9pf789_crop_2.jpg', 0.8248725), ('EJxP8coPRimuJX2uk85NPZvm4rfeTy747_crop_1.jpg', 0.82440394), ('ADrmYzHX2AgmZ6xWL5MPAquix69Mbf191_crop_2.jpg', 0.8240521), ('wDgU5FUwd8slnsyZqTeWiEK9PnmhAI512_crop_1.jpg', 0.82372177), ('happy_dog_841_crop_ ...

# %% [markdown]
# 남은 happy 데이터 중에서 hap_face_vector와 유사한 데이터 200개를 새로운 폴더로 이동

# %%
happy_feature_dict=file_move('/content/happy_train_img',hap_body_list,happy_feature_dict)

# %% [markdown]
# ### play와 유사한 이미지 100장 추출

# %%
unzip_file('play.zip')
unzip_file('dog_play_crop_img.zip')

# %%
play_feature_dict=pkl_load('play_feature_dict.pkl')

# %%
hap_play_vector=mean_vector('play')
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
hap_play_list=cor('dog_play_crop_img',100,play_feature_dict,hap_play_vector)
# Out:
# [('dog_351_crop_1.jpg', 0.86603165), ('dog_38_crop_1.jpg', 0.8505391), ('dog_107_crop_1.jpg', 0.8478582), ('dog_368_crop_1.jpg', 0.8478396), ('dog_383_crop_2.jpg', 0.84776986), ('dog_225_crop_1.jpg', 0.8464482), ('dog_360_crop_1.jpg', 0.8448675), ('dog_361_crop_1.jpg', 0.84449637), ('dog_359_crop_3.jpg', 0.8433934), ('dog_709_crop_1.jpg', 0.8422948), ('dog_710_crop_1.jpg', 0.84181464), ('dog_70_crop_1.jpg', 0.83996695), ('dog_590_crop_1.jpg', 0.83825207), ('dog_448_crop_1.jpg', 0.836641), ('dog_618_crop_1.jpg', 0.8362254), ('dog_392_crop_1.jpg', 0.8362202), ('dog_473_crop_1.jpg', 0.83475226), ('dog_347_crop_1.jpg', 0.8335177), ('dog_364_crop_1.jpg', 0.8330883), ('dog_60_crop_1.jpg', 0.83275723), ('dog_411_crop_1.jpg', 0.8322841), ('dog_118_crop_2.jpg', 0.83192533), ('dog_451_crop_1.jpg', 0.83185416), ('dog_288_crop_1.jpg', 0.8312609), ('dog_178_crop_1.jpg', 0.8310127), ('dog_243_crop_1.jpg', 0.8307017), ('dog_725_crop_1.jpg', 0.8303301), ('dog_389_crop_1.jpg', 0.8302338), ('dog_967_crop_1.jpg', 0.82999885), ('dog_550_crop_1.jpg', 0.8298311), ('dog_419_crop_1.jpg', 0.82973564), ('dog_121_crop_1.jpg', 0.8286825), ('dog_138_crop_1.jpg', 0.8285644), ('dog_701_crop_1.jpg', 0.8283186), ('dog_588_crop_1.jpg', 0.8281829), ('dog_6_crop_1.jpg', 0.8278483), ('dog_346_crop_2.jpg', 0.82782435), ('dog_101_crop_1.jpg', 0.8275979), ('dog_246_crop_1.jpg', 0.827386), ('dog_66_crop_1.jpg', 0.8270521), ('dog_159_crop_1.jpg', 0.827032), ('dog_863_crop_1.jpg', 0.82691306), ('dog_186_crop_1.jpg', 0.8261662), ('dog_7_crop_1.jpg', 0.8259206), ('dog_31_crop_1.jpg', 0.8252212), ('dog_283_crop_1.jpg', 0.8251857), ('dog_316_crop_1.jpg', 0.82481885), ('dog_119_crop_1.jpg', 0.8244065), ('dog_660_crop_1.jpg', 0.82427686), ('dog_640_crop_2.jpg', 0.82399696), ('dog_809_crop_1.jpg', 0.82387847), ('dog_72_crop_1.jpg', 0.82376796), ('dog_742_crop_1.jpg', 0.82356954), ('dog_687_crop_1.jpg', 0.823488), ('dog_659_crop_1.jpg', 0.822201), ('dog_91_crop_1.jpg', 0.8221451), ('dog_572_crop_1.jpg', 0.8219787), ('dog_469_crop_1.jpg', 0.82183677), ('dog_440_crop_1.jpg', 0.8207186), ('dog_475_crop_1.jpg', 0.8206793), ('dog_720_crop_2.jpg', 0.8204521), ('dog_84_crop_1.jpg', 0.82022643), ('dog_449_crop_1.jpg', 0.82006854), ('dog_436_crop_1.jpg', 0.8196515), ('dog_117_crop_1.jpg', 0.8193606), ('dog_211_crop_1.jpg', 0.81925046), ('dog_758_crop_1.jpg', 0.8191904), ('dog_753_crop_1.jpg', 0.8191319), ('dog_253_crop_1.jpg', 0.8191217), ('dog_425_crop_1.jpg', 0.8186306), ('dog_607_crop_1.jpg', 0.8184012), ('dog_418_crop_1.jpg', 0.81808275), ('dog_237_crop_1.jpg', 0.818082), ('dog_65_crop_1.jpg', 0.8179281), ('dog_665_crop_1.jpg', 0.81768095), ('dog_774_crop_3.jpg', 0.81758344), ('dog_309_crop_1.jpg', 0.81733954), ('dog_223_crop_1.jpg', 0.8171583), ('dog_928_crop_1.jpg', 0.8169014), ('dog_711_crop_1.jpg', 0.8168644), ('dog_721_crop_2.jpg', 0.81652856), ('dog_391_crop_1.jpg', 0.8164904), ('dog_486_crop_1.jpg', 0.81623536), ('dog_252_crop_1.jpg', 0.8160727), ('dog_131_crop_1.jpg', 0.81598896), ('dog_46_crop_1.jpg', 0.8157813), ('dog_82_crop_1.jpg', 0.81568193), ('dog_756_crop_1.jpg', 0.8155317), ('dog_249_crop_2.jpg', 0.8151421), ('dog_8_crop_1.jpg', 0.8149533), ('dog_638_crop_1.jpg', 0.81470895), ('dog_614_crop_1.jpg', 0.81469464), ('dog_245_crop_1.jpg', 0.8143827), ('dog_251_crop_1.jpg', 0.8142817), ('dog_631_crop_2.jpg', 0.81427145), ('dog_705_crop_1.jpg', 0.8142326), ('dog_170_crop_1.jpg', 0.8141963), ('dog_308_crop_1.jpg', 0.8140551), ('dog_430_crop_1.jpg', 0.8139911), ('dog_728_crop_1.jpg', 0.81364584), ('dog_580_crop_1.jpg', 0.81361014), ('dog_544_crop_1.jpg', 0.8134151), ('dog_69_crop_1.jpg', 0.81321186), ('dog_307_crop_1.jpg', 0.81305873), ('dog_616_crop_2.jpg', 0.8128058), ('dog_273_crop_1.jpg', 0.8125738), ('dog_30_crop_1.jpg', 0.8125148), ('dog_272_crop_1.jpg', 0.81228375), ('dog_164_crop_1.jpg', 0.8122803), ('dog_679_crop_1.jpg', 0.812052), ('dog_71_crop_1.jpg', 0.8118193), ('dog_499_crop_1.jpg', 0.8117648), ('dog_462_crop_1.jpg', 0.8114756), ('dog_958_crop_1.jpg', 0.811260 ...

# %% [markdown]
# 남은 happy 데이터 중에서 hap_play_vector와 유사한 데이터 100개를 새로운 폴더로 이동

# %%
play_feature_dict=file_move('/content/happy_train_img',hap_play_list,play_feature_dict)

# %%
folder_path = '/content/happy_train_img'

if os.path.exists(folder_path):
    file_count = len([f for f in os.listdir(folder_path) if os.path.isfile(os.path.join(folder_path, f))])
    print(f"폴더 '{folder_path}'에 있는 파일 개수: {file_count}")
else:
    print(f"폴더 '{folder_path}'가 존재하지 않습니다.")
# Out:
# 폴더 '/content/happy_train_img'에 있는 파일 개수: 500

# %%
shutil.make_archive('happy_train_img', 'zip', 'happy_train_img')
# Out:
# '/content/happy_train_img.zip'
